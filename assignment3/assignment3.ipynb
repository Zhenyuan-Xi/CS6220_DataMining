# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pd.set_option("display.max_columns", 100) 
url = "https://ww2.amstat.org/publications/jse/v19n3/Decock/AmesHousing.txt" 
df = pd.read_csv(url, sep="\t")

# %%
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1   NaN       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 2   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 3   NaN       Reg          Lvl    AllPub     Corner        Gtl        NAmes
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
# ...

# %%
np.count_nonzero(df.isnull().sum())

# 27 features have missing values.
# Out:
# 27

# %%
df.update(df.select_dtypes(exclude=[np.number]).fillna("Missing"))
df.head(20)
# Out:
#     Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0       1  526301100           20        RL         141.0     31770   Pave
# 1       2  526350040           20        RH          80.0     11622   Pave
# 2       3  526351010           20        RL          81.0     14267   Pave
# 3       4  526353030           20        RL          93.0     11160   Pave
# 4       5  527105010           60        RL          74.0     13830   Pave
# 5       6  527105030           60        RL          78.0      9978   Pave
# 6       7  527127150          120        RL          41.0      4920   Pave
# 7       8  527145080          120        RL          43.0      5005   Pave
# 8       9  527146030          120        RL          39.0      5389   Pave
# 9      10  527162130           60        RL          60.0      7500   Pave
# 10     11  527163010           60        RL          75.0     10000   Pave
# ...

# %%
df.update(df.select_dtypes(include=[np.number]).interpolate())
df.head(20)
# Out:
#     Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0       1  526301100           20        RL         141.0     31770   Pave
# 1       2  526350040           20        RH          80.0     11622   Pave
# 2       3  526351010           20        RL          81.0     14267   Pave
# 3       4  526353030           20        RL          93.0     11160   Pave
# 4       5  527105010           60        RL          74.0     13830   Pave
# 5       6  527105030           60        RL          78.0      9978   Pave
# 6       7  527127150          120        RL          41.0      4920   Pave
# 7       8  527145080          120        RL          43.0      5005   Pave
# 8       9  527146030          120        RL          39.0      5389   Pave
# 9      10  527162130           60        RL          60.0      7500   Pave
# 10     11  527163010           60        RL          75.0     10000   Pave
# ...

# %%
df_ori = df.copy()
df_ori.head(20)
# Out:
#     Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0       1  526301100           20        RL         141.0     31770   Pave
# 1       2  526350040           20        RH          80.0     11622   Pave
# 2       3  526351010           20        RL          81.0     14267   Pave
# 3       4  526353030           20        RL          93.0     11160   Pave
# 4       5  527105010           60        RL          74.0     13830   Pave
# 5       6  527105030           60        RL          78.0      9978   Pave
# 6       7  527127150          120        RL          41.0      4920   Pave
# 7       8  527145080          120        RL          43.0      5005   Pave
# 8       9  527146030          120        RL          39.0      5389   Pave
# 9      10  527162130           60        RL          60.0      7500   Pave
# 10     11  527163010           60        RL          75.0     10000   Pave
# ...

# %%
scaler = preprocessing.StandardScaler()
cols = df.select_dtypes(include=[np.number]).drop(['Order', 'PID', 'SalePrice'], axis=1).columns
df2 = df.copy()
df2[cols] = scaler.fit_transform(df[cols])
df.update(df2)
df.head(20)
# Out:
#     Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0       1  526301100    -0.877005        RL      3.128744  2.744381   Pave
# 1       2  526350040    -0.877005        RH      0.459721  0.187097   Pave
# 2       3  526351010    -0.877005        RL      0.503475  0.522814   Pave
# 3       4  526353030    -0.877005        RL      1.028529  0.128458   Pave
# 4       5  527105010     0.061285        RL      0.197194  0.467348   Pave
# 5       6  527105030     0.061285        RL      0.372212 -0.021567   Pave
# 6       7  527127150     1.468720        RL     -1.246704 -0.663554   Pave
# 7       8  527145080     1.468720        RL     -1.159195 -0.652765   Pave
# 8       9  527146030     1.468720        RL     -1.334213 -0.604026   Pave
# 9      10  527162130     0.061285        RL     -0.415369 -0.336087   Pave
# 10     11  527163010     0.061285        RL      0.240948 -0.018775   Pave
# ...

# %%
matplotlib.style.use('fivethirtyeight')
# plot with standardization

plt1 = df.select_dtypes(include=[np.number]).drop(['Order', 'PID', 'SalePrice'], axis=1).boxplot(grid=False, figsize=(25, 20), rot=90, showmeans=True);

# %%
# plot without standardization

plt2 = df_ori.select_dtypes(include=[np.number]).drop(['Order', 'PID', 'SalePrice'], axis=1).boxplot(grid=False, figsize=(25, 20), rot=90, showmeans=True);

# %%
# Since the values of y-axis are relatively smaller, the data of each feature is more discrete but still in the same distribution,
# so it's more clear to see the outliers after standardization.
# after standardization, the mean value and unit variance are both 0.

# before standardization, the feature having the furthest outlier is 'Lot Area'
# after standardization, the feature having the furthest outlier above is 'Misc Val', furthest outlier below is 'Kitchen AbvGr'

# %%
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import SelectKBest

# %%
numerics = df.select_dtypes(include=[np.number]).drop(['Order', 'PID'], axis=1)
X = numerics.iloc[:, :-1]
y = numerics.iloc[:, -1]

# %%
mi = mutual_info_regression(X, y)
print(mi)
# Out:
# d:\python\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# [0.28155839 0.21421669 0.16681019 0.58211054 0.13555498 0.40024155
#  0.29583221 0.16820582 0.17870077 0.         0.11717661 0.39352431
#  0.36869372 0.21590333 0.         0.49696237 0.04220449 0.
#  0.25368485 0.05708903 0.05438487 0.02279904 0.18685251 0.18327483
#  0.30958004 0.38911828 0.42057216 0.10256926 0.1854109  0.03933071
#  0.         0.0216393  0.         0.00591006 0.         0.03195215]

# %%
selector = SelectKBest(mutual_info_regression, k=5)
selector.fit(X, y)

idxs_selected = selector.get_support(indices=True)

X_new = X.iloc[:, idxs_selected]

print(X_new.head(20))

# top 5 most informative numeric features are 'Overall Qual', 'Year Built', 'Total Bsmt SF', 'Gr Liv Area' and 'Garage Area'.
# Out:
# d:\python\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
#     Overall Qual  Year Built  Total Bsmt SF  Gr Liv Area  Garage Area
# 0      -0.067254   -0.375537       0.064758     0.309265     0.257066
# 1      -0.776079   -0.342468      -0.384699    -1.194427     1.196425
# 2      -0.067254   -0.441674       0.629983    -0.337718    -0.747397
# 3       0.641571   -0.110988       2.402840     1.207523     0.229164
# 4      -0.776079    0.848000      -0.280280     0.255844     0.043152
# 5      -0.067254    0.881068      -0.284820     0.206381    -0.012651
# 6       1.350396    0.980274       0.650413    -0.319911     0.508182
# 7       1.350396    0.682657       0.518754    -0.434667     0.154760
# 8       1.350396    0.781863       1.233799     0.230123     0.629089
# 9       0.641571    0.914137      -0.130461     0.602089    -0.142859
# ...

# %%
fig, axes = plt.subplots(3, 2, figsize=(20,38))
df.plot.scatter(x="Overall Qual", y="SalePrice", ax=axes[0,0])
df.plot.scatter(x="Year Built", y="SalePrice", ax=axes[0,1])
df.plot.scatter(x="Total Bsmt SF", y="SalePrice", ax=axes[1,0])
df.plot.scatter(x="Gr Liv Area", y="SalePrice", ax=axes[1,1])
df.plot.scatter(x="Garage Area", y="SalePrice", ax=axes[2,0])

# as shown in the correlation plot below, the sale price would increse when the values of top 5 features go up
# although the 'Year Built' and 'Garage Area' do not show the very obvious positively associated relation, 
# they still have the trend that newer the house is or larger the garage area, higher the sale price.
